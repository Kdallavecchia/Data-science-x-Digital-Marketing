# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r'C:\Users\kevda\OneDrive\Desktop\Lavoro\neogela\Excel\Marketing\Report kw 10-01.xlsx')

# %%
df.head()
# Out:
#   Stato della parola chiave         Parola chiave   Tipo di corrispondenza  \
# 0                  Attivato   integratore neogela  Corrispondenza generica
# 1                  Attivato     neogela collagene  Corrispondenza generica
# 2                  Attivato    neogela recensioni  Corrispondenza generica
# 3                  Attivato               neogela  Corrispondenza generica
# 4                  Attivato  neogela composizione  Corrispondenza generica
#
#    Campagna Gruppo di annunci       Stato    Motivi dello stato Codice valuta  \
# 0  B-Search          Branding      Idoneo                   NaN           EUR
# 1  B-Search          Branding      Idoneo                   NaN           EUR
# 2  B-Search          Branding      Idoneo                   NaN           EUR
# 3  B-Search          Branding      Idoneo                   NaN           EUR
# 4  B-Search          Branding  Non idoneo  pubblicato raramente           EUR
#
# ...

# %%
df.columns
# Out:
# Index(['Stato della parola chiave', 'Parola chiave', 'Tipo di corrispondenza',
#        'Campagna', 'Gruppo di annunci', 'Stato', 'Motivi dello stato',
#        'Codice valuta', 'CPC max', 'Impressioni', 'Clic', 'CPC medio',
#        'Conversioni', 'CTR', 'Costo/conv.', 'Tasso conv.', 'Costo'],
#       dtype='object')

# %%
df.shape
# Out:
# (131, 17)

# %%
df['Tipo di corrispondenza'].unique()
# Out:
# array(['Corrispondenza generica', 'Corrispondenza esatta',
#        'Corrispondenza a frase', 'Totale: Parole chiave attivate',
#        'Totale: Parole chiave per la ricerca sulla Rete Display',
#        'Totale: Account', 'Totale: Ricerca'], dtype=object)

# %%
df = df.drop(['Motivi dello stato','Stato', 'Codice valuta','CPC max','Stato della parola chiave'], axis=1)

# %%
columns = ['Impressioni','Clic', 'CPC medio', 'Conversioni', 'CTR','Costo/conv.', 'Tasso conv.', 'Costo']

# %%
df.groupby('Parola chiave')[columns].sum()
# Out:
#                                  Impressioni  Clic  Conversioni  Costo/conv.  \
# Parola chiave
# "bustine collagene"                        0     0          0.0         0.00
# "bustine di collagene"                     0     0          0.0         0.00
# "collagene articolazioni"                  0     0          0.0         0.00
# "collagene artrosi"                        0     0          0.0         0.00
# "collagene benefici"                       0     0          0.0         0.00
# ...                                      ...   ...          ...          ...
# rimedi naturali osteoporosi               76     6          0.0         0.00
# rimedi naturali per osteoporosi           43     0          0.0         0.00
# rimedi per osteoporosi                 13513  1443          2.0        26.90
# terapia naturale osteoporosi              38     3          0.0         0.00
# terapia per osteoporosi                14475   665          3.0         7.96
#
# ...

# %%
df.groupby('Parola chiave')['Impressioni','Conversioni'].sum()
# Out:
# <ipython-input-11-57e1f9cd9d2b>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Parola chiave')['Impressioni','Conversioni'].sum()
#                                  Impressioni  Conversioni
# Parola chiave
# "bustine collagene"                        0          0.0
# "bustine di collagene"                     0          0.0
# "collagene articolazioni"                  0          0.0
# "collagene artrosi"                        0          0.0
# "collagene benefici"                       0          0.0
# ...                                      ...          ...
# rimedi naturali osteoporosi               76          0.0
# rimedi naturali per osteoporosi           43          0.0
# rimedi per osteoporosi                 13513          2.0
# terapia naturale osteoporosi              38          0.0
# terapia per osteoporosi                14475          3.0
#
# [123 rows x 2 columns]

# %%
df.describe().transpose().round(3)
# Out:
#              count      mean        std  min  25%  50%      75%         max
# Impressioni  131.0  4054.031  23509.879  0.0  0.0  5.0  194.000  229379.000
# Clic         131.0   215.656   1081.762  0.0  0.0  0.0   13.500    7558.000
# Conversioni  131.0     4.649     23.887  0.0  0.0  0.0    0.000     175.060
# Costo/conv.  131.0     7.079     41.799  0.0  0.0  0.0    0.000     389.050
# Tasso conv.  131.0     0.016      0.053  0.0  0.0  0.0    0.000       0.372
# Costo        131.0    20.564    105.562  0.0  0.0  0.0    1.755     819.250

# %%
df.tail()
# Out:
#                          Parola chiave  \
# 126  rimedi alternativi ai bifosfonati
# 127                                NaN
# 128                                NaN
# 129                                NaN
# 130                                NaN
#
#                                 Tipo di corrispondenza               Campagna  \
# 126                            Corrispondenza generica  Conversione Barattoli
# 127                     Totale: Parole chiave attivate                    NaN
# 128  Totale: Parole chiave per la ricerca sulla Ret...                    NaN
# 129                                    Totale: Account                    NaN
# 130                                    Totale: Ricerca                    NaN
#
#        Gruppo di annunci  Impressioni  Clic CPC medio  Conversioni     CTR  \
# 126  Altre - Commerciali           24     1      0.05         0.00  0.0417
# 127                  NaN       100363  6878      0.09       143.97  0.0685
# ...

# %%
df.drop(index=[127,128,129,130], inplace=True)

# %%
df.tail()
# Out:
#                          Parola chiave   Tipo di corrispondenza  \
# 122          [integratore osteoporosi]    Corrispondenza esatta
# 123        cura per rinforzare le ossa  Corrispondenza generica
# 124                cura per osteopenia  Corrispondenza generica
# 125       cure naturali per osteopenia  Corrispondenza generica
# 126  rimedi alternativi ai bifosfonati  Corrispondenza generica
#
#                   Campagna    Gruppo di annunci  Impressioni  Clic CPC medio  \
# 122  Conversione Barattoli  Altre - Commerciali            1     0        --
# 123  Conversione Barattoli  Altre - Commerciali            0     0        --
# 124  Conversione Barattoli  Altre - Commerciali          169     5      0.05
# 125  Conversione Barattoli  Altre - Commerciali            0     0        --
# 126  Conversione Barattoli  Altre - Commerciali           24     1      0.05
#
#      Conversioni     CTR  Costo/conv.  Tasso conv.  Costo
# 122         0.00       0         0.00       0.0000   0.00
# ...

# %%
df.dtypes
# Out:
# Parola chiave              object
# Tipo di corrispondenza     object
# Campagna                   object
# Gruppo di annunci          object
# Impressioni                 int64
# Clic                        int64
# CPC medio                  object
# Conversioni               float64
# CTR                        object
# Costo/conv.               float64
# Tasso conv.               float64
# Costo                     float64
# dtype: object

# %%
df.set_index('Parola chiave',inplace=True, )
#imposto parola chiave come indice!

# %%
df.sort_index(ascending=True,inplace=True)

# %%
df.sort_values(by='Conversioni',ascending=False)
# Out:
#                                    Tipo di corrispondenza  \
# Parola chiave
# neogela                           Corrispondenza generica
# integratore osteoporosi           Corrispondenza generica
# integratore collagene             Corrispondenza generica
# collagene integratore             Corrispondenza generica
# neogela collagene                 Corrispondenza generica
# ...                                                   ...
# [collagene idrolizzato migliore]    Corrispondenza esatta
# [collagene concentrato]             Corrispondenza esatta
# [collagene cartilagine]             Corrispondenza esatta
# [collagene benefici]                Corrispondenza esatta
# collagene artrite                 Corrispondenza generica
#
#                                                Campagna  \
# Parola chiave
# neogela                                        B-Search
# integratore osteoporosi           Conversione Barattoli
# integratore collagene             Conversione Barattoli
# ...

# %%
df['Gruppo di annunci'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[['Conversioni', 'Impressioni','Clic']].idxmax()
# Out:
# Conversioni                    neogela
# Impressioni    prevenzione osteoporosi
# Clic           prevenzione osteoporosi
# dtype: object

# %%
df.loc[['integratore osteoporosi','collagene integratore']]
# Out:
#                           Tipo di corrispondenza               Campagna  \
# Parola chiave
# integratore osteoporosi  Corrispondenza generica               Traffico
# integratore osteoporosi  Corrispondenza generica  Conversione Barattoli
# collagene integratore    Corrispondenza generica  Conversione Barattoli
#
#                              Gruppo di annunci  Impressioni  Clic CPC medio  \
# Parola chiave
# integratore osteoporosi     Gruppo Integratore         6523   225      0.05
# integratore osteoporosi    Altre - Commerciali          221    62      0.15
# collagene integratore    Collagene Commerciale          318    86      0.26
#
#                          Conversioni     CTR  Costo/conv.  Tasso conv.  Costo
# Parola chiave
# integratore osteoporosi         4.06  0.0345         2.62       0.0180  10.63
# integratore osteoporosi        14.65  0.2805         0.63       0.2363   9.20
# collagene integratore          11.05  0.2704         1.99       0.1285  22.04

# %%
df.nlargest(n=10,columns=['Conversioni'])
#metto in ordine e visualizzo i primi 10 valori in ordine di conversioni
# Out:
#                                    Tipo di corrispondenza  \
# Parola chiave
# neogela                           Corrispondenza generica
# integratore osteoporosi           Corrispondenza generica
# integratore collagene             Corrispondenza generica
# collagene integratore             Corrispondenza generica
# neogela collagene                 Corrispondenza generica
# collagene integratore alimentare  Corrispondenza generica
# integratore osteoporosi           Corrispondenza generica
# prevenzione osteoporosi           Corrispondenza generica
# integratori naturali osteoporosi  Corrispondenza generica
# integratori naturali osteoporosi  Corrispondenza generica
#
#                                                Campagna  \
# Parola chiave
# neogela                                        B-Search
# integratore osteoporosi           Conversione Barattoli
# integratore collagene             Conversione Barattoli
# collagene integratore             Conversione Barattoli
# ...

# %%
df.sort_values(by='Conversioni', ascending=False).head(10)
# Out:
#                                    Tipo di corrispondenza  \
# Parola chiave
# neogela                           Corrispondenza generica
# integratore osteoporosi           Corrispondenza generica
# integratore collagene             Corrispondenza generica
# collagene integratore             Corrispondenza generica
# neogela collagene                 Corrispondenza generica
# collagene integratore alimentare  Corrispondenza generica
# integratore osteoporosi           Corrispondenza generica
# prevenzione osteoporosi           Corrispondenza generica
# integratori naturali osteoporosi  Corrispondenza generica
# integratori naturali osteoporosi  Corrispondenza generica
#
#                                                Campagna  \
# Parola chiave
# neogela                                        B-Search
# integratore osteoporosi           Conversione Barattoli
# integratore collagene             Conversione Barattoli
# collagene integratore             Conversione Barattoli
# ...

# %%
df['Tipo di corrispondenza'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.isna().any().sum()
# Out:
# 0

# %%
df['Conversioni'].sum()
# Out:
# 143.96

# %%
df['Conversioni'].mean()
# Out:
# 1.133543307086614

# %%
df['Clic'].sum()
# Out:
# 6878

# %%
df['Conversion Rate'] = df['Conversioni'] / df['Clic']*100
df['Conversion Rate'].sort_values(ascending=False)
# Out:
# Parola chiave
# collagene integratore alimentare          37.200000
# integratore osteoporosi                   23.629032
# miglior integratore di collagene          23.000000
# integratori naturali osteoporosi          21.428571
# integratore collagene                     21.377049
#                                             ...
# osteoporosi cure naturali                       NaN
# osteoporosi prevenzione                         NaN
# osteoporosi rimedi                              NaN
# prevenire osteoporosi in modo naturale          NaN
# rimedi naturali per osteoporosi                 NaN
# Name: Conversion Rate, Length: 127, dtype: float64

# %%
df.fillna(value=0)
# Out:
#                                   Tipo di corrispondenza  \
# Parola chiave
# "bustine collagene"               Corrispondenza a frase
# "bustine di collagene"            Corrispondenza a frase
# "collagene articolazioni"         Corrispondenza a frase
# "collagene artrosi"               Corrispondenza a frase
# "collagene benefici"              Corrispondenza a frase
# ...                                                  ...
# rimedi naturali osteoporosi      Corrispondenza generica
# rimedi naturali per osteoporosi  Corrispondenza generica
# rimedi per osteoporosi           Corrispondenza generica
# terapia naturale osteoporosi     Corrispondenza generica
# terapia per osteoporosi          Corrispondenza generica
#
#                                               Campagna  \
# Parola chiave
# "bustine collagene"              Conversione Barattoli
# "bustine di collagene"           Conversione Barattoli
# "collagene articolazioni"        Conversione Barattoli
# ...

# %%
df.sort_values(by='Conversion Rate',ascending=False).head(25).round(2)
# Out:
#                                                Tipo di corrispondenza  \
# Parola chiave
# collagene integratore alimentare              Corrispondenza generica
# integratore osteoporosi                       Corrispondenza generica
# miglior integratore di collagene              Corrispondenza generica
# integratori naturali osteoporosi              Corrispondenza generica
# integratore collagene                         Corrispondenza generica
# collagene integratore                         Corrispondenza generica
# neogela                                       Corrispondenza generica
# collagene per ossa                            Corrispondenza generica
# collagene per osteoporosi                     Corrispondenza generica
# il miglior collagene                          Corrispondenza generica
# neogela collagene                             Corrispondenza generica
# neogela composizione                          Corrispondenza generica
# ...

# %%
#sostituire le -- con valore nullo funzione map di pandas
df[df['CPC medio'] == '--']
# Out:
#                                          Tipo di corrispondenza  \
# Parola chiave
# "bustine collagene"                      Corrispondenza a frase
# "bustine di collagene"                   Corrispondenza a frase
# "collagene articolazioni"                Corrispondenza a frase
# "collagene artrosi"                      Corrispondenza a frase
# "collagene benefici"                     Corrispondenza a frase
# ...                                                         ...
# osteoporosi cure naturali               Corrispondenza generica
# osteoporosi prevenzione                 Corrispondenza generica
# osteoporosi rimedi                      Corrispondenza generica
# prevenire osteoporosi in modo naturale  Corrispondenza generica
# rimedi naturali per osteoporosi         Corrispondenza generica
#
#                                                      Campagna  \
# Parola chiave
# "bustine collagene"                     Conversione Barattoli
# ...

# %%
mask1 = df['CPC medio'] == '--'
df[mask1]
# Out:
#                                          Tipo di corrispondenza  \
# Parola chiave
# "bustine collagene"                      Corrispondenza a frase
# "bustine di collagene"                   Corrispondenza a frase
# "collagene articolazioni"                Corrispondenza a frase
# "collagene artrosi"                      Corrispondenza a frase
# "collagene benefici"                     Corrispondenza a frase
# ...                                                         ...
# osteoporosi cure naturali               Corrispondenza generica
# osteoporosi prevenzione                 Corrispondenza generica
# osteoporosi rimedi                      Corrispondenza generica
# prevenire osteoporosi in modo naturale  Corrispondenza generica
# rimedi naturali per osteoporosi         Corrispondenza generica
#
#                                                      Campagna  \
# Parola chiave
# "bustine collagene"                     Conversione Barattoli
# ...

# %%
mask2 = df['Conversioni'] > df['Conversioni'].mean()
df[mask2].sort_values(by='Conversioni',ascending=False)
# Out:
#                                    Tipo di corrispondenza  \
# Parola chiave
# neogela                           Corrispondenza generica
# integratore osteoporosi           Corrispondenza generica
# integratore collagene             Corrispondenza generica
# collagene integratore             Corrispondenza generica
# neogela collagene                 Corrispondenza generica
# collagene integratore alimentare  Corrispondenza generica
# integratore osteoporosi           Corrispondenza generica
# prevenzione osteoporosi           Corrispondenza generica
# integratori naturali osteoporosi  Corrispondenza generica
# integratori naturali osteoporosi  Corrispondenza generica
# terapia per osteoporosi           Corrispondenza generica
# collagene per le ossa             Corrispondenza generica
# miglior integratore di collagene  Corrispondenza generica
# rimedi per osteoporosi            Corrispondenza generica
# il miglior collagene              Corrispondenza generica
# ...

# %%
df = df.replace(['--'],0)
#replace cambia tutti i valori di un tipo in altro

# %%
mask1 = df['CPC medio'] == '--'
df[mask1]
# Out:
# Empty DataFrame
# Columns: [Tipo di corrispondenza, Campagna, Gruppo di annunci, Impressioni, Clic, CPC medio, Conversioni, CTR, Costo/conv., Tasso conv., Costo, Conversion Rate]
# Index: []

# %%
df
# Out:
#                                   Tipo di corrispondenza  \
# Parola chiave
# "bustine collagene"               Corrispondenza a frase
# "bustine di collagene"            Corrispondenza a frase
# "collagene articolazioni"         Corrispondenza a frase
# "collagene artrosi"               Corrispondenza a frase
# "collagene benefici"              Corrispondenza a frase
# ...                                                  ...
# rimedi naturali osteoporosi      Corrispondenza generica
# rimedi naturali per osteoporosi  Corrispondenza generica
# rimedi per osteoporosi           Corrispondenza generica
# terapia naturale osteoporosi     Corrispondenza generica
# terapia per osteoporosi          Corrispondenza generica
#
#                                               Campagna  \
# Parola chiave
# "bustine collagene"              Conversione Barattoli
# "bustine di collagene"           Conversione Barattoli
# "collagene articolazioni"        Conversione Barattoli
# ...

# %%
df = df.fillna(value=0)

# %%
df.isnull().sum()
# Out:
# Tipo di corrispondenza    0
# Campagna                  0
# Gruppo di annunci         0
# Impressioni               0
# Clic                      0
# CPC medio                 0
# Conversioni               0
# CTR                       0
# Costo/conv.               0
# Tasso conv.               0
# Costo                     0
# Conversion Rate           0
# dtype: int64

# %%
stat = df.groupby(by=['Tipo di corrispondenza','Gruppo di annunci'])
len(stat)
# Out:
# 15

# %%
stat.sum().sort_values(by='Conversioni',ascending=False)
# Out:
#                                                    Impressioni  Clic  \
# Tipo di corrispondenza  Gruppo di annunci
# Corrispondenza generica Branding                          3172   806
#                         Collagene Commerciale              406   106
#                         Collagene - Transazionali          390    93
#                         Altre - Commerciali                475    71
#                         Gruppo Osteoporosi               76540  5026
#                         Gruppo Integratore               16619   595
#                         Gruppo Collagene                  2418   153
#                         Osteoporosi - commerciali          123    14
# Corrispondenza a frase  Collagene - Transazionali            0     0
#                         Collagene Commerciale               29     6
#                         Osteoporosi - commerciali          103     4
# Corrispondenza esatta   Altre - Commerciali                  1     0
# ...

# %%
df.groupby(by='Conversioni').agg({'Impressioni':['max','min','mean'],
                                  'Clic':['max','min','mean']}).round(2).sort_values(by='Conversioni',ascending=False)
# Out:
#             Impressioni                  Clic
#                     max    min     mean   max   min     mean
# Conversioni
# 59.96              1766   1766   1766.0   518   518   518.00
# 14.65               221    221    221.0    62    62    62.00
# 13.04               229    229    229.0    61    61    61.00
# 11.05               318    318    318.0    86    86    86.00
# 7.91                799    799    799.0   139   139   139.00
# 7.44                 88     88     88.0    20    20    20.00
# 4.06               6523   6523   6523.0   225   225   225.00
# 3.93              21579  21579  21579.0  1456  1456  1456.00
# 3.22               6142   6142   6142.0   221   221   221.00
# 3.00              14475    123   7299.0   665    14   339.50
# 2.24                529    529    529.0    64    64    64.00
# 2.07                 34     34     34.0     9     9     9.00
# 2.00              13513  13513  13513.0  1443  1443  1443.00
# ...

# %%
df['Tipo di corrispondenza'].unique()
# Out:
# array(['Corrispondenza a frase', 'Corrispondenza esatta',
#        'Corrispondenza generica'], dtype=object)

# %%
#df['Tipo di corrispondenza'] = df['Tipo di corrispondenza'].map({'Corrispondenza a frase':2, 'Corrispondenza esatta':1,'Corrispondenza generica':3})

# %%
df['Gruppo di annunci'].unique()
# Out:
# array(['Collagene - Transazionali', 'Collagene Commerciale',
#        'Osteoporosi - commerciali', 'Altre - Commerciali',
#        'Gruppo Collagene', 'Gruppo Osteoporosi', 'Gruppo Integratore',
#        'Branding'], dtype=object)

# %%
df['Campagna'].unique()
# Out:
# array(['Conversione Barattoli', 'Traffico', 'B-Search'], dtype=object)

# %%
#df['Campagna'] = df['Campagna'].map({'Conversione Barattoli':1,'Traffico':2,'B-Search':3})

# %%
#df['Gruppo di annunci'] = df['Gruppo di annunci'].map({'Collagene - Transazionali':1, 'Collagene Commerciale':2,
       #'Osteoporosi - commerciali':3, 'Altre - Commerciali':4, 'Gruppo Collagene':5, 'Gruppo Osteoporosi':6,'Gruppo Integratore':7,'Branding':8})

# %%
df.sort_values(by='Conversioni', ascending=False).round(2)
# Out:
#                                    Tipo di corrispondenza  \
# Parola chiave
# neogela                           Corrispondenza generica
# integratore osteoporosi           Corrispondenza generica
# integratore collagene             Corrispondenza generica
# collagene integratore             Corrispondenza generica
# neogela collagene                 Corrispondenza generica
# ...                                                   ...
# [collagene idrolizzato migliore]    Corrispondenza esatta
# [collagene concentrato]             Corrispondenza esatta
# [collagene cartilagine]             Corrispondenza esatta
# [collagene benefici]                Corrispondenza esatta
# collagene artrite                 Corrispondenza generica
#
#                                                Campagna  \
# Parola chiave
# neogela                                        B-Search
# integratore osteoporosi           Conversione Barattoli
# integratore collagene             Conversione Barattoli
# ...

# %%
df.isna().sum()
# Out:
# Tipo di corrispondenza    0
# Campagna                  0
# Gruppo di annunci         0
# Impressioni               0
# Clic                      0
# CPC medio                 0
# Conversioni               0
# CTR                       0
# Costo/conv.               0
# Tasso conv.               0
# Costo                     0
# Conversion Rate           0
# dtype: int64

# %%
df.pivot_table(values='Conversioni',
    index=['Campagna','Parola chiave'],
    columns='Tipo di corrispondenza',
    aggfunc='sum').fillna(0).sort_values(by='Corrispondenza generica',ascending=False).head(30)
# Out:
# Tipo di corrispondenza                                              Corrispondenza a frase  \
# Campagna              Parola chiave
# B-Search              neogela                                                          0.0
# Conversione Barattoli integratore osteoporosi                                          0.0
#                       integratore collagene                                            0.0
#                       collagene integratore                                            0.0
# B-Search              neogela collagene                                                0.0
# Conversione Barattoli collagene integratore alimentare                                 0.0
# Traffico              integratore osteoporosi                                          0.0
#                       prevenzione osteoporosi                                          0.0
#                       integratori naturali osteoporosi                                 0.0
# ...

# %%
mask4= df['Conversioni'] >= 5
df[mask4]
# Out:
#                                    Tipo di corrispondenza  \
# Parola chiave
# collagene integratore             Corrispondenza generica
# collagene integratore alimentare  Corrispondenza generica
# integratore collagene             Corrispondenza generica
# integratore osteoporosi           Corrispondenza generica
# neogela                           Corrispondenza generica
# neogela collagene                 Corrispondenza generica
#
#                                                Campagna  \
# Parola chiave
# collagene integratore             Conversione Barattoli
# collagene integratore alimentare  Conversione Barattoli
# integratore collagene             Conversione Barattoli
# integratore osteoporosi           Conversione Barattoli
# neogela                                        B-Search
# neogela collagene                              B-Search
#
#                                           Gruppo di annunci  Impressioni  \
# Parola chiave
# ...

# %%
# %matplotlib inline
#non è codice python ma serve per fa visualizzare direttamente i grafici sul notebook

# %%
df[mask4].plot()
# Out:
# <AxesSubplot:xlabel='Parola chiave'>

# %%
df[mask4].plot(y = 'Conversioni', figsize=(10,15))
# con y= scelgo quale colonna visualizzare
# Out:
# <AxesSubplot:xlabel='Parola chiave'>

# %%
df.plot(y = ['Clic','Impressioni'],figsize=(15,10),rot=45)
# Out:
# <AxesSubplot:xlabel='Parola chiave'>

# %%
df[mask4].plot(subplots=True, figsize=(15,10))
#divido ogni colonna in tanti grafici
# Out:
# array([<AxesSubplot:xlabel='Parola chiave'>,
#        <AxesSubplot:xlabel='Parola chiave'>,
#        <AxesSubplot:xlabel='Parola chiave'>,
#        <AxesSubplot:xlabel='Parola chiave'>,
#        <AxesSubplot:xlabel='Parola chiave'>,
#        <AxesSubplot:xlabel='Parola chiave'>,
#        <AxesSubplot:xlabel='Parola chiave'>,
#        <AxesSubplot:xlabel='Parola chiave'>,
#        <AxesSubplot:xlabel='Parola chiave'>], dtype=object)

# %%
#mask4= df['Conversioni'] >= 5
df[mask4].plot(y='CPC medio',figsize=(20,5),c='green',use_index=False,linewidth=3)
plt.title('CPC medio', fontsize=15)
plt.legend(loc='upper left',fontsize=15)
plt.xlabel('kw che convertono maggiormente',fontsize=15)
plt.ylabel('€',fontsize=20)
plt.grid()

# %%
df[mask4].plot(y=['CPC medio','CTR'],figsize=(20,5),cmap='Set1',rot=90,linewidth=3)
plt.title('CPC medio', fontsize=15)
plt.legend(loc='upper left',fontsize=15)
plt.xlabel('kw che convertono maggiormente',fontsize=15)
plt.ylabel('€',fontsize=20)
plt.grid()

# %%
df[mask4].plot(y=['CPC medio','CTR'],figsize=(20,5),cmap='Set1',rot=90,linewidth=3,kind='bar')
plt.title('CPC medio', fontsize=15)
plt.legend(loc='upper left',fontsize=15)
plt.xlabel('kw che convertono maggiormente',fontsize=15)
plt.ylabel('€',fontsize=20)
plt.grid()
